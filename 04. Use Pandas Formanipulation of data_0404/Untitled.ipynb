# %%
import pandas as pd
import numpy as np

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")

# %%
customerData.columns = ["CUDTID", "AVERAGEPRICE", "EMI", "DEVICECOUNT", "PRODUCTAGE", "CUSTTYPE"]

# %%
customerData = pd.DataFrame(customerData)

# %%
customerData.head()
# Out:
#    CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
customerData[customerData.EMI>=3].head()
# Out:
#     CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27  F17131   3179.708359    3          6.5    1.100000        Early-bird
# 33  G16437   3787.328898    3          6.7    1.000000        Early-bird
# 36  G18402   3402.199381    3          6.5    1.000000        Early-bird
# 40  H16326   3988.935304    3          6.5    0.900000        Early-bird

# %%
customerData.dtypes
# Out:
# CUDTID           object
# AVERAGEPRICE    float64
# EMI               int64
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
dfc1 = customerData.iloc[0:6,[1,3]]
dfc1
# Out:
#    AVERAGEPRICE  DEVICECOUNT
# 0   4273.900000          6.4
# 1   3642.441950          4.0
# 2   3653.884565          5.0
# 3   3713.211107          6.6
# 4   3391.074215          4.2
# 5   3755.263391          4.7

# %%
customerData["PRODUCTAGE_NEW"] = np.where(customerData["PRODUCTAGE"] < 1,1,\
                                 np.where(customerData["PRODUCTAGE"] < 2,2,\
                                 np.where(customerData["PRODUCTAGE"] < 3,3,5)))
customerData.head()
# Out:
#    CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3
# 2               5
# 3               1
# 4               3

# %%
sampleData = pd.read_csv("../dataset/kopo_customerdata.csv")


sampleData[["CUSTOMERCODE", "STATENAME","GENDER","TOTAL_AMOUNT"]]

choo = sampleData.iloc[0:6,[1,3]]


columns =sampleData.columns
columns
customerNO = columns.get_loc("CUSTOMERCODE")
emailNO = columns.get_loc("EMAIL")
choo = sampleData.iloc[0:6,[customerNO,emailNO]]

# %%
def refining(df):
    if df['PRODUCTAGE'] < 1:
        return 1
    elif df['PRODUCTAGE'] < 2:
        return 2
    else:
        return 5

# %%
customerData["PRODUCTAGE_NEW2"] = customerData.apply(refining, axis = 1)
customerData.head()
# Out:
#    CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# 0               2                2
# 1               3                5
# 2               5                5
# 3               1                1
# 4               3                5

# %% [markdown]
# ### 데이터 정렬하기

# %%
sortKey = ["CUDTID", "AVERAGEPRICE"]

# %%
customerData.sort_values(sortKey, ascending=[False,False]).head()

# inplace 기본 값  > False  TRUE일 경우 정렬된 값이 저장됨
# Out:
#      CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 149  Z19835   3326.526183    2          6.7    1.200000        Early-bird
# 148  Z16735   3300.100000    2          5.6    1.704942  Big-Screen-lover
# 147  Z16428   3516.500000    2          5.8    2.371301  Big-Screen-lover
# 146  Z13534   3662.437527    3          6.6    0.900000        Early-bird
# 145  Z13253   3678.800000    2          5.9    2.463670  Big-Screen-lover
#
#      PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# 149               2                2
# 148               2                2
# 147               3                5
# 146               1                1
# 145               3                5

# %%
groupKey=["CUSTTYPE","EMI"]

# %%
groupData = customerData.\
groupby(groupKey, as_index=True).\
mean()
groupData
# Out:
#                       AVERAGEPRICE  DEVICECOUNT  PRODUCTAGE  PRODUCTAGE_NEW  \
# CUSTTYPE         EMI
# Big-Screen-lover 1     3246.000000     5.000000    1.891624        2.000000
#                  2     3535.317391     5.508696    2.223247        2.804348
#                  3     4111.600000     6.400000    1.838520        2.333333
# Early-bird       1     2390.083736     6.300000    1.000000        2.000000
#                  2     3232.445885     6.460606    0.936364        1.242424
#                  3     3455.966035     6.475000    0.962500        1.437500
# Sleeping-dog     1     3185.918464     3.833333    2.357587        2.777778
#                  2     3504.298670     4.353659    2.724274        3.463415
#
#                       PRODUCTAGE_NEW2
# CUSTTYPE         EMI
# Big-Screen-lover 1           2.000000
#                  2           4.152174
#                  3           3.000000
# Early-bird       1           2.000000
#                  2           1.242424
# ...

# %%
customerData2 = pd.read_csv("../dataset/customerdata.csv")

# %%
customerData2.columns = ["CUDTID", "AVERAGEPRICE", "EMI", "DEVICECOUNT", "PRODUCTAGE", "CUSTTYPE"]

# %%
customerData2.head()
# Out:
#    CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
order = 5
import math
suborder = math.floor(order/2)
suborder
# Out:
# 2

# %%
customerData2["TEST"] = customerData2["PRODUCTAGE"].rolling(window = 5, center = True).mean()

# %%
customerData2.head(20)
# Out:
#     CUDTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0   A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1   A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2   A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3   A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4   B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5   B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6   B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7   C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8   C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9   C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10  C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11  C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
regionMasterData = pd.read_csv("../dataset/kopo_region_mst.csv")

# %%
selectExample = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
